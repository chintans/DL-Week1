# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data: [study_hours, sleep_hours]
X = np.array([
    [1, 3],
    [2, 2],
    [3, 6],
    [4, 3],
    [5, 2],
    [1, 6]
])

# Labels: 1 = Pass, 0 = Fail
y = np.array([0, 0, 1, 1, 1, 0])

# Initialize weights and bias
weights = np.random.rand(2)
bias = 0
learning_rate = 0.1

# %%
def step(z):
    return 1 if z > 0 else 0

# Training loop
for epoch in range(10):
    for i in range(len(X)):
        z = np.dot(X[i], weights) + bias
        pred = step(z)
        error = y[i] - pred
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

# Final model weights
print("Trained weights:", weights)
print("Trained bias:", bias)
# Out:
# Trained weights: [ 1.18470524 -0.4348575 ]
# Trained bias: -0.7

# %%
# Prediction
def predict(study, sleep):
    z = np.dot([study, sleep], weights) + bias
    return step(z)

# %%
# Plot data points
for i in range(len(X)):
    color = 'green' if y[i] == 1 else 'red'
    plt.scatter(X[i][0], X[i][1], color=color)

# Decision boundary
x_vals = np.linspace(0, 6, 100)
y_vals = -(weights[0] * x_vals + bias) / weights[1]
plt.plot(x_vals, y_vals, label='Decision Boundary')

plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Pass/Fail Classification Using Perceptron")
plt.legend()
plt.grid(True)
plt.show()
